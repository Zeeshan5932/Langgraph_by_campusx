# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
import os
from langchain_groq import ChatGroq

# %%
load_dotenv()
# Out:
# True

# %%
# model = ChatOpenAI()
model = ChatGroq(
    groq_api_key=os.getenv("GROQ_API_KEY"),
    model = "llama-3.1-8b-instant"
)

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt)

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# content='The average distance from the Earth to the Moon is approximately 238,855 miles (384,400 kilometers). However, this distance varies slightly due to the elliptical shape of the Moon\'s orbit around the Earth.\n\nAt its closest point, called "perigee," the Moon is about 225,623 miles (363,104 kilometers) away from the Earth. At its farthest point, called "apogee," the Moon is about 252,088 miles (405,696 kilometers) away.\n\nSo, to summarize:\n\n- Average distance: 238,855 miles (384,400 kilometers)\n- Perigee (closest point): 225,623 miles (363,104 kilometers)\n- Apogee (farthest point): 252,088 miles (405,696 kilometers)' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 163, 'prompt_tokens': 47, 'total_tokens': 210, 'completion_time': 0.196026573, 'completion_tokens_details': None, 'prompt_time': 0.002328676, 'prompt_tokens_details': None, 'queue_time': 0.005173093, 'total_time': 0.198355249}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019cd232-19d4-7093-b622-e654f5b93040-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 47, 'output_tokens': 163, 'total_tokens': 210}

# %%
model.invoke('How far is moon from the earth?').content
# Out:
# 'The average distance from the Earth to the Moon is approximately 384,400 kilometers (238,855 miles). This is called the "lunar distance" or "lunar mean distance." However, the Moon\'s orbit is not a perfect circle and its distance from Earth varies slightly over the course of a month.\n\nAt its closest point (called "perigee"), the Moon is about 363,300 kilometers (225,623 miles) away from Earth. At its farthest point (called "apogee"), the Moon is about 405,500 kilometers (252,000 miles) away from Earth.\n\nIt\'s worth noting that the distance between the Earth and the Moon is constantly changing due to the gravitational interactions between the two bodies and the tidal interactions with the Sun.'
