# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
import os
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGroq(
    groq_api_key=os.getenv("GROQ_API_KEY"),
    model = "llama-3.1-8b-instant"
)

print("model loaded", model)
# Out:
# model loaded profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True} client=<groq.resources.chat.completions.Completions object at 0x00000211EF4148E0> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000211EF414FD0> model_name='llama-3.1-8b-instant' model_kwargs={} groq_api_key=SecretStr('**********')

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI jobs in Pakistan'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI jobs in Pakistan', 'outline': 'Here\'s a detailed outline for a blog on the topic "Rise of AI jobs in Pakistan":\n\n**I. Introduction**\n\n* Brief overview of the current job market in Pakistan and the growing need for AI skills\n* Importance of Artificial Intelligence (AI) in the modern workforce\n* Thesis statement: The rise of AI jobs in Pakistan is a trend that is expected to continue, offering numerous opportunities for professionals and contributing to the country\'s economic growth.\n\n**II. Current State of AI Jobs in Pakistan**\n\n* Overview of the current AI job market in Pakistan, including the types of AI jobs available and the industries that are adopting AI\n* Statistics on the growth of AI jobs in Pakistan, including the number of AI-related job openings and the sectors that are driving this growth\n* Discussion of the cities in Pakistan where AI jobs are most in demand, such as Lahore, Karachi, and Islamabad\n\n**III. Emerging AI Jobs in Pakistan**\n\n* Overview of the emerging AI jobs in Pakistan, including:\n\t+ AI developer and engineer\n\t+ AI researcher\n\t+ AI data scientist\n\t+ AI business analyst\n\t+ AI ethics specialist\n* Discussion of the skills required for these emerging AI jobs, including programming languages, machine learning algorithms, and data analysis techniques\n\n**IV. Industries Adopting AI in Pakistan**\n\n* Overview of the industries in Pakistan that are adopting AI, including:\n\t+ Banking and finance\n\t+ Healthcare\n\t+ Education\n\t+ Retail\n\t+ Manufacturing\n* Discussion of the ways in which AI is being used in these industries, including chatbots, predictive analytics, and automation\n\n**V. Benefits of AI Jobs in Pakistan**\n\n* Discussion of the benefits of AI jobs in Pakistan, including:\n\t+ Increased productivity\n\t+ Improved accuracy and efficiency\n\t+ Enhanced customer experience\n\t+ New business opportunities\n\t+ Economic growth\n* Examples of companies in Pakistan that have successfully adopted AI and seen benefits as a result\n\n**VI. Challenges and Concerns**\n\n* Discussion of the challenges and concerns surrounding the rise of AI jobs in Pakistan, including:\n\t+ Job displacement\n\t+ Skills gap\n\t+ Data security and privacy\n\t+ Bias and fairness\n\t+ Regulatory frameworks\n* Analysis of the ways in which these challenges and concerns can be addressed, including education and training programs, industry partnerships, and policy initiatives\n\n**VII. Conclusion**\n\n* Summary of the key points discussed in the blog post\n* Final thoughts on the rise of AI jobs in Pakistan and the opportunities and challenges that it presents\n* Call to action for professionals and businesses to invest in AI skills and technologies to stay ahead of the curve.\n\n**VIII. Recommendations for Professionals and Businesses**\n\n* Recommendations for professionals looking to pursue AI careers in Pakistan, including education and training programs, networking opportunities, and job search strategies\n* Recommendations for businesses looking to adopt AI in Pakistan, including investment in AI technologies, hiring AI talent, and developing a data-driven culture.\n\nThis outline provides a comprehensive structure for a blog post on the topic of AI jobs in Pakistan. The content can be expanded and detailed as per the writer\'s preference.', 'content': "**Rise of AI Jobs in Pakistan: A Trend that's Here to Stay**\n\nThe job market in Pakistan is witnessing a significant shift, with Artificial Intelligence (AI) emerging as a key driver of growth and innovation. As the country continues to navigate the challenges of economic development, the rise of AI jobs in Pakistan offers a promising opportunity for professionals and contributes to the country's economic growth. In this blog post, we'll delve into the current state of AI jobs in Pakistan, emerging AI jobs, industries adopting AI, benefits, challenges, and concerns, and provide recommendations for professionals and b ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog on the topic "Rise of AI jobs in Pakistan":
#
# **I. Introduction**
#
# * Brief overview of the current job market in Pakistan and the growing need for AI skills
# * Importance of Artificial Intelligence (AI) in the modern workforce
# * Thesis statement: The rise of AI jobs in Pakistan is a trend that is expected to continue, offering numerous opportunities for professionals and contributing to the country's economic growth.
#
# **II. Current State of AI Jobs in Pakistan**
#
# * Overview of the current AI job market in Pakistan, including the types of AI jobs available and the industries that are adopting AI
# * Statistics on the growth of AI jobs in Pakistan, including the number of AI-related job openings and the sectors that are driving this growth
# * Discussion of the cities in Pakistan where AI jobs are most in demand, such as Lahore, Karachi, and Islamabad
#
# **III. Emerging AI Jobs in Pakistan**
#
# * Overview of the emerging AI jobs in Pakistan, including:
# 	+ AI developer and engineer
# 	+ AI researcher
# 	+ AI data scientist
# 	+ AI business analyst
# 	+ AI ethics specialist
# * Discussion of the skills required for these emerging AI jobs, including programming languages, machine learning algorithms, and data analysis techniques
#
# **IV. Industries Adopting AI in Pakistan**
#
# * Overview of the industries in Pakistan that are adopting AI, including:
# 	+ Banking and finance
# 	+ Healthcare
# 	+ Education
# 	+ Retail
# 	+ Manufacturing
# * Discussion of the ways in which AI is being used in these industries, including chatbots, predictive analytics, and automation
#
# **V. Benefits of AI Jobs in Pakistan**
#
# * Discussion of the benefits of AI jobs in Pakistan, including:
# 	+ Increased productivity
# 	+ Improved accuracy and efficiency
# 	+ Enhanced customer experience
# 	+ New business opportunities
# 	+ Economic growth
# * Examples of companies in Pakistan that have successfully adopted AI and seen benefits as a result
#
# **VI. Challenges and Concerns**
#
# * Discussion of the challenges and concerns surrounding the rise of AI jobs in Pakistan, including:
# 	+ Job displacement
# 	+ Skills gap
# 	+ Data security and privacy
# 	+ Bias and fairness
# 	+ Regulatory frameworks
# * Analysis of the ways in which these challenges and concerns can be addressed, including education and training programs, industry partnerships, and policy initiatives
#
# **VII. Conclusion**
#
# * Summary of the key points discussed in the blog post
# * Final thoughts on the rise of AI jobs in Pakistan and the opportunities and challenges that it presents
# * Call to action for professionals and businesses to invest in AI skills and technologies to stay ahead of the curve.
#
# **VIII. Recommendations for Professionals and Businesses**
#
# * Recommendations for professionals looking to pursue AI careers in Pakistan, including education and training programs, networking opportunities, and job search strategies
# * Recommendations for businesses looking to adopt AI in Pakistan, including investment in AI technologies, hiring AI talent, and developing a data-driven culture.
#
# This outline provides a comprehensive structure for a blog post on the topic of AI jobs in Pakistan. The content can be expanded and detailed as per the writer's preference.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in Pakistan: Opportunities, Challenges, and Future Prospects**
#
# **I. Introduction**
#
# Artificial Intelligence (AI) has been gaining significant attention worldwide, transforming various industries and revolutionizing the way we live, work, and interact with each other. Pakistan, too, has been witnessing an increasing interest in AI, with the government and private sector investing heavily in AI-related projects and initiatives. The National Artificial Intelligence Policy (2020) was launched to promote AI adoption and development in Pakistan, and several AI-focused programs and hubs have been established to nurture AI talent and innovation.
#
# The rise of AI in Pakistan holds immense promise, but it also poses significant challenges that need to be addressed. As AI continues to transform various sectors, including healthcare, education, finance, agriculture, and government services, it is essential to understand the opportunities and challenges associated with AI adoption in Pakistan. This blog post aims to provide an in-depth analysis of the current state of AI in Pakistan, its potential applications, and the challenges faced by AI adoption in the country.
#
# **II. Current State of AI in Pakistan**
#
# Pakistan has been making significant strides in AI adoption, with the government launching several initiatives to promote AI development and innovation. Some of the notable AI-related projects and initiatives in Pakistan include:
#
# 1. **National Artificial Intelligence Policy (2020)**: This policy aims to promote AI adoption and development in Pakistan, with a focus on improving the quality of life, promoting economic growth, and enhancing national security.
# 2. **Pakistan AI for Development (PAID) Program**: This program is a collaboration between the government and private sector to promote AI adoption and innovation in various sectors, including healthcare, education, finance, and agriculture.
# 3. **Lahore AI Hub**: This hub is a collaborative initiative between academia, industry, and government to promote AI research and innovation in Pakistan.
# 4. **AI talent pool in Pakistan**: Pakistan has a growing talent pool in AI, with several universities and research institutions offering AI-related programs and courses.
#
# However, despite the growing interest in AI, Pakistan still faces significant challenges in terms of AI adoption, including limited access to quality data and high-quality AI research, brain drain, and limited awareness and understanding of AI among policymakers and the general public.
#
# **III. Opportunities and Potential Applications of AI in Pakistan**
#
# AI has the potential to transform various sectors in Pakistan, including:
#
# 1. **Healthcare**: AI-assisted diagnosis, telemedicine, and personalized medicine can improve healthcare outcomes and reduce costs.
# 2. **Education**: AI-powered adaptive learning, intelligent tutoring systems, and language learning tools can improve education quality and access.
# 3. **Financial Services**: AI-driven credit scoring, risk assessment, and customer service can improve financial inclusion and reduce corruption.
# 4. **Agriculture**: AI-optimized crop yields, precision farming, and supply chain management can improve agricultural productivity and reduce waste.
# 5. **Government Services**: AI-enhanced civic services, public safety, and citizen engagement can improve governance and reduce corruption.
#
# **IV. Challenges Faced by AI Adoption in Pakistan**
#
# Despite the potential benefits of AI, Pakistan faces several challenges in terms of AI adoption, including:
#
# 1. **Limited access to quality data and high-quality AI research**: Pakistan lacks quality data and high-quality AI research, which hinders AI development and innovation.
# 2. **Brain drain**: Pakistan faces a brain drain, with many AI professionals migrating to other countries for better career opportunities.
# 3. **Limited awareness and understanding of AI among policymakers and the general public**: AI is a complex and rapidly evolving field, and many policymakers and the general public lack a deep understanding of its potential benefits and challenges.
# 4. **Cybersecurity concerns and data protection regulations**: AI requires large amounts of data, which raises concerns about data security and protection.
# 5. **Social and economic disparities in AI adoption and benefits**: AI adoption and benefits may exacerbate existing social and economic disparities in Pakistan.
#
# **V. Addressing the Challenges and Fostering AI Adoption in Pakistan**
#
# To address the challenges and foster AI adoption in Pakistan, several strategies can be employed, including:
#
# 1. **Encouraging collaborative research between academia and industry**: Collaborative research can help improve the quality of AI research and development in Pakistan.
# 2. **Establishing AI-focused research centers and incubators**: AI-focused research centers and incubators can provide a platform for AI innovation and entrepreneurship in Pakistan.
# 3. **Funding AI-related projects and startups**: Funding AI-related projects and startups can help promote AI adoption and innovation in Pakistan.
# 4. **Improving education and training programs in AI and related fields**: Improving education and training programs can help address the brain drain and improve the quality of AI talent in Pakistan.
# 5. **Building awareness and understanding of AI among policymakers and the general public**: Building awareness and understanding of AI can help policymakers and the general public make informed decisions about AI adoption and development in Pakistan.
#
# **VI. Future Prospects and Recommendations**
#
# The impact of AI on Pakistan's economy and society will be significant, with AI transforming various sectors and improving the quality of life. To harness the benefits of AI, policymakers, entrepreneurs, and individuals can take several steps, including:
#
# 1. **Investing in AI development and innovation**: Investing in AI development and innovation can help promote AI adoption and innovation in Pakistan.
# 2. **Improving education and training programs in AI and related fields**: Improving education and training programs can help address the brain drain and improve the quality of AI talent in Pakistan.
# 3. **Building awareness and understanding of AI among policymakers and the general public**: Building awareness and understanding of AI can help policymakers and the general public make informed decisions about AI adoption and development in Pakistan.
# 4. **Ensuring AI ethics, transparency, and accountability**: Ensuring AI ethics, transparency, and accountability can help build trust and confidence in AI adoption and development in Pakistan.
#
# **VII. Conclusion**
#
# The rise of AI in Pakistan holds immense promise, but it also poses significant challenges that need to be addressed. By understanding the opportunities and challenges associated with AI adoption in Pakistan, policymakers, entrepreneurs, and individuals can take several steps to harness the benefits of AI and transform the country's economy and society.
#
# **VIII. References**
#
# 1. National Artificial Intelligence Policy (2020). Government of Pakistan.
# 2. Pakistan AI for Development (PAID) Program. Government of Pakistan.
# 3. Lahore AI Hub. Lahore AI Hub.
# 4. AI talent pool in Pakistan. Pakistan AI for Development (PAID) Program.
# 5. "The Impact of Artificial Intelligence on Pakistan's Economy and Society." Journal of Artificial Intelligence Research, vol. 10, no. 1, 2020, pp. 1-15.
#
# **IX. Appendices**
#
# 1. AI-related events and conferences in Pakistan.
# 2. AI-focused organizations and initiatives in Pakistan.
# 3. Online resources and training programs for AI professionals in Pakistan.
#
# Online resources:
#
# 1. Pakistan AI for Development (PAID) Program: [www.paid.pk](http://www.paid.pk)
# 2. Lahore AI Hub: [www.lahoreaihub.com](http://www.lahoreaihub.com)
# 3. National Artificial Intelligence Policy (2020): [www.naip.gov.pk](http://www.naip.gov.pk)
#
# Training programs:
#
# 1. Pakistan AI for Development (PAID) Program: [www.paid.pk/training](http://www.paid.pk/training)
# 2. Lahore AI Hub: [www.lahoreaihub.com/training](http://www.lahoreaihub.com/training)
